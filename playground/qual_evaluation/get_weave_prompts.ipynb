# %%
import weave

client = weave.init("gsm8k_evaluation_few_shot")
calls = client.get_calls(
    filter={"trace_roots_only": True},
    sort_by=[{"field":"started_at","direction":"desc"}],
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import weave
#       3 client = weave.init("gsm8k_evaluation_few_shot")
#       4 calls = client.get_calls(
#       5     filter={"trace_roots_only": True},
#       6     sort_by=[{"field":"started_at","direction":"desc"}],
#       7 )
#
# ModuleNotFoundError: No module named 'weave'
